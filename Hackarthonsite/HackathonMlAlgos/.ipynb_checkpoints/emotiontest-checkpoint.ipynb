# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/sanatpopli/anaconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /Users/sanatpopli/anaconda3/lib/python3.11/site-packages (from opencv-python) (1.24.3)

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load your trained model
model = load_model("predictemotionmodel.keras")

# Define labels and colors for the results
results = {0: 'Sad/depressed', 1: 'Happy/Normal'}
GR_dict = {0: (0, 0, 255), 1: (0, 255, 0)}

# Initialize video capture
cap = cv2.VideoCapture(0)

# Load the Haar cascade for frontal face detection
haarcascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, im = cap.read()
    if not ret:
        break  # Exit loop if unable to capture frame
    im = cv2.flip(im, 1, 1)  # Flip the frame

    # Convert to grayscale for face detection
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    faces = haarcascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        cv2.rectangle(im, (x, y), (x+w, y+h), (255, 0, 0), 2)
        face_img = im[y:y+h, x:x+w]
        rerect_sized = cv2.resize(face_img, (150, 150))
        normalized = rerect_sized / 255.0
        reshaped = np.reshape(normalized, (1, 150, 150, 3))
        result = model.predict(reshaped)

        label = np.argmax(result, axis=1)[0]

        cv2.rectangle(im, (x, y), (x+w, y+h), GR_dict[label], 2)
        cv2.rectangle(im, (x, y-40), (x+w, y), GR_dict[label], -1)
        cv2.putText(im, results[label], (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    cv2.imshow('LIVE', im)
    key = cv2.waitKey(10)

    if key == 27:  # Exit on ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 111ms/step
# 1   HIToolbox                           0x00000001b62e45c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001b62e4188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x00000001b62518bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x00000001b62e4004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x00000001b00d3d30 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x00000001aff6993c -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x00000001acb86560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x00000001acc24044 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00000001acc23f8c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x00000001acb57b64 _CFXNotificationPost + 708
# 11  Foundation                          0x00000001ada4738c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x00000001b00d42b4 spacesNotificationHandler + 96
# 13  SkyLight                            0x00000001b17c1214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x00000001b17bfe10 CGSSnarfAndDispatchDatagrams + 808
# 15  SkyLight                            0x00000001b1ae7a9c SLSGetNextEventRecordInternal + 344
# 16  SkyLight                            0x00000001b18e8fb0 SLEventCreateNextEvent + 16
# 17  HIToolbox                           0x00000001b627cb58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 18  HIToolbox                           0x00000001b627cae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 19  CoreFoundation                      0x00000001acbc1410 __CFMachPortPerform + 260
# 20  CoreFoundation                      0x00000001acb91f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 21  CoreFoundation                      0x00000001acb91eb8 __CFRunLoopDoSource1 + 520
# 22  CoreFoundation                      0x00000001acb908a4 __CFRunLoopRun + 2264
# 23  CoreFoundation                      0x00000001acb8f878 CFRunLoopRunSpecific + 612
# 24  HIToolbox                           0x00000001b626ffa0 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00000001b626fc30 ReceiveNextEventCommon + 236
# 26  HIToolbox                           0x00000001b626fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 27  AppKit                              0x00000001afe1584c _DPSNextEvent + 632
# 28  AppKit                              0x00000001afe149dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 29  cv2.abi3.so                         0x00000001528b6ed8 cvWaitKey + 476
# 30  cv2.abi3.so                         0x00000001528b0f6c _ZN2cv9waitKeyExEi + 168
# 31  cv2.abi3.so                         0x00000001528b1064 _ZN2cv7waitKeyEi + 48
# 32  cv2.abi3.so                         0x0000000151dfe968 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.11                          0x000000010236385c cfunction_call + 60
# 34  python3.11                          0x00000001024461cc _PyEval_EvalFrameDefault + 195528
# 35  python3.11                          0x0000000102413b90 _PyEval_Vector + 464
# 36  python3.11                          0x0000000102413930 PyEval_EvalCode + 248
# 37  python3.11                          0x000000010240eb10 builtin_exec + 332
# 38  python3.11                          0x0000000102449c30 _PyEval_EvalFrameDefault + 210476
# 39  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 40  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 41  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 42  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 43  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 44  python3.11                          0x000000010231e74c gen_send + 52
# 45  python3.11                          0x0000000102312cb0 method_vectorcall_O + 104
# 46  python3.11                          0x0000000102445fd8 _PyEval_EvalFrameDefault + 195028
# 47  python3.11                          0x0000000102301538 _PyFunction_Vectorcall + 476
# 48  python3.11                          0x000000010230722c method_vectorcall + 272
# 49  python3.11                          0x000000010244aee4 _PyEval_EvalFrameDefault + 215264
# 50  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 51  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 52  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 53  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 54  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 55  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 56  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 57  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 58  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 59  _asyncio.cpython-311-darwin.so      0x000000010301c370 task_step_impl + 440
# 60  _asyncio.cpython-311-darwin.so      0x000000010301c128 task_step + 68
# 61  _asyncio.cpython-311-darwin.so      0x000000010301cc30 task_wakeup + 136
# 62  python3.11                          0x000000010236422c cfunction_vectorcall_O + 92
# 63  python3.11                          0x000000010246e7ac _PyObject_VectorcallTstate.4605 + 88
# 64  python3.11                          0x000000010246e670 context_run + 92
# 65  python3.11                          0x000000010236450c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 66  python3.11                          0x000000010244af90 _PyEval_EvalFrameDefault + 215436
# 67  python3.11                          0x0000000102413b90 _PyEval_Vector + 464
# 68  python3.11                          0x0000000102413930 PyEval_EvalCode + 248
# 69  python3.11                          0x000000010240eb10 builtin_exec + 332
# 70  python3.11                          0x000000010236450c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 71  python3.11                          0x0000000102445fd8 _PyEval_EvalFrameDefault + 195028
# 72  python3.11                          0x0000000102301538 _PyFunction_Vectorcall + 476
# 73  python3.11                          0x00000001024cea5c pymain_run_module + 212
# 74  python3.11                          0x00000001024ce4f4 Py_RunMain + 1292
# 75  python3.11                          0x0000000102299474 main + 56
# 76  dyld                                0x00000001ac787e50 start + 2544
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1   HIToolbox                           0x00000001b626f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x00000001b62e4fbc _ZN15MenuBarInstance15DisableAutoShowEv + 36
# 3   HIToolbox                           0x00000001b62e50b0 _ZN15MenuBarInstanceD2Ev + 128
# 4   HIToolbox                           0x00000001b62e4ee0 _ZN15MenuBarInstance7ReleaseEv + 56
# 5   AppKit                              0x00000001b04714dc -[NSHIPresentationInstance discard] + 228
# 6   AppKit                              0x00000001b08308b4 -[_NSFullScreenSpace(PresentationInstance) discardPresentationInstance] + 32
# 7   AppKit                              0x00000001b083090c -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 64
# 8   AppKit                              0x00000001b068a968 -[_NSExitFullScreenTransitionController _doSucceededToExitFullScreen] + 40
# 9   AppKit                              0x00000001b068b440 __63-[_NSExitFullScreenTransitionController _performExitFullScreen]_block_invoke + 236
# 10  libxpc.dylib                        0x00000001ac82242c _xpc_connection_reply_callout + 124
# 11  libxpc.dylib                        0x00000001ac82231c _xpc_connection_call_reply_async + 88
# 12  libdispatch.dylib                   0x00000001ac92a584 _dispatch_client_callout3 + 20
# 13  libdispatch.dylib                   0x00000001ac948710 _dispatch_mach_msg_async_reply_invoke + 344
# 14  libdispatch.dylib                   0x00000001ac938c70 _dispatch_main_queue_drain + 756
# 15  libdispatch.dylib                   0x00000001ac93896c _dispatch_main_queue_callback_4CF + 44
# 16  CoreFoundation                      0x00000001acbd2d40 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 16
# 17  CoreFoundation                      0x00000001acb907c0 __CFRunLoopRun + 2036
# 18  CoreFoundation                      0x00000001acb8f878 CFRunLoopRunSpecific + 612
# 19  HIToolbox                           0x00000001b626ffa0 RunCurrentEventLoopInMode + 292
# 20  HIToolbox                           0x00000001b626fde4 ReceiveNextEventCommon + 672
# 21  HIToolbox                           0x00000001b626fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 22  AppKit                              0x00000001afe1584c _DPSNextEvent + 632
# 23  AppKit                              0x00000001afe149dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 24  cv2.abi3.so                         0x00000001528b6ed8 cvWaitKey + 476
# 25  cv2.abi3.so                         0x00000001528b0f6c _ZN2cv9waitKeyExEi + 168
# 26  cv2.abi3.so                         0x00000001528b1064 _ZN2cv7waitKeyEi + 48
# 27  cv2.abi3.so                         0x0000000151dfe968 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 28  python3.11                          0x000000010236385c cfunction_call + 60
# 29  python3.11                          0x00000001024461cc _PyEval_EvalFrameDefault + 195528
# 30  python3.11                          0x0000000102413b90 _PyEval_Vector + 464
# 31  python3.11                          0x0000000102413930 PyEval_EvalCode + 248
# 32  python3.11                          0x000000010240eb10 builtin_exec + 332
# 33  python3.11                          0x0000000102449c30 _PyEval_EvalFrameDefault + 210476
# 34  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 35  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 36  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 37  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 38  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 39  python3.11                          0x000000010231e74c gen_send + 52
# 40  python3.11                          0x0000000102312cb0 method_vectorcall_O + 104
# 41  python3.11                          0x0000000102445fd8 _PyEval_EvalFrameDefault + 195028
# 42  python3.11                          0x0000000102301538 _PyFunction_Vectorcall + 476
# 43  python3.11                          0x000000010230722c method_vectorcall + 272
# 44  python3.11                          0x000000010244aee4 _PyEval_EvalFrameDefault + 215264
# 45  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 46  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 47  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 48  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 49  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 50  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 51  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 52  python3.11                          0x0000000102420f90 _PyEval_EvalFrameDefault + 43404
# 53  python3.11                          0x000000010231dff4 gen_send_ex2 + 204
# 54  _asyncio.cpython-311-darwin.so      0x000000010301c370 task_step_impl + 440
# 55  _asyncio.cpython-311-darwin.so      0x000000010301c128 task_step + 68
# 56  _asyncio.cpython-311-darwin.so      0x000000010301cc30 task_wakeup + 136
# 57  python3.11                          0x000000010236422c cfunction_vectorcall_O + 92
# 58  python3.11                          0x000000010246e7ac _PyObject_VectorcallTstate.4605 + 88
# 59  python3.11                          0x000000010246e670 context_run + 92
# 60  python3.11                          0x000000010236450c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  python3.11                          0x000000010244af90 _PyEval_EvalFrameDefault + 215436
# 62  python3.11                          0x0000000102413b90 _PyEval_Vector + 464
# 63  python3.11                          0x0000000102413930 PyEval_EvalCode + 248
# 64  python3.11                          0x000000010240eb10 builtin_exec + 332
# 65  python3.11                          0x000000010236450c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 66  python3.11                          0x0000000102445fd8 _PyEval_EvalFrameDefault + 195028
# 67  python3.11                          0x0000000102301538 _PyFunction_Vectorcall + 476
# 68  python3.11                          0x00000001024cea5c pymain_run_module + 212
# 69  python3.11                          0x00000001024ce4f4 Py_RunMain + 1292
# 70  python3.11                          0x0000000102299474 main + 56
# 71  dyld                                0x00000001ac787e50 start + 2544
